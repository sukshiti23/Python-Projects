# %% [markdown]
# **📊SPOTIFY 2023 DATA ANALYSIS**

# %% [markdown]
# The aim of this project is :
# 📍Perform EDA
# 📍Determine the most and least streamed song
# 📍Determine most and least streamed artist
# 📍Compare the streams of artists
# 📍Visualize the data
# 📍Analyze top artists and tracks

# %% [markdown]
# Import the necessary libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Load the spotify dataset

# %%
data=pd.read_csv('spotify-2023.csv',encoding='latin1')

# %%
data
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %% [markdown]
# Displaying the columns in the dataset in the form of list

# %%
data.columns.tolist()
# Out:
# ['track_name',
#  'artist(s)_name',
#  'artist_count',
#  'released_year',
#  'released_month',
#  'released_day',
#  'in_spotify_playlists',
#  'in_spotify_charts',
#  'streams',
#  'in_apple_playlists',
#  'in_apple_charts',
#  'in_deezer_playlists',
#  'in_deezer_charts',
#  'in_shazam_charts',
#  'bpm',
#  'key',
#  'mode',
#  'danceability_%',
#  'valence_%',
#  'energy_%',
#  'acousticness_%',
#  'instrumentalness_%',
#  'liveness_%',
#  'speechiness_%']

# %% [markdown]
# Checking for null values

# %%
data.isnull()
# Out:
#      track_name  artist(s)_name  artist_count  released_year  released_month  \
# 0         False           False         False          False           False
# 1         False           False         False          False           False
# 2         False           False         False          False           False
# 3         False           False         False          False           False
# 4         False           False         False          False           False
# ..          ...             ...           ...            ...             ...
# 948       False           False         False          False           False
# 949       False           False         False          False           False
# 950       False           False         False          False           False
# 951       False           False         False          False           False
# 952       False           False         False          False           False
#
# ...

# %%
data.isnull().sum()
# Out:
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64

# %% [markdown]
# Shape and Size of the dataset

# %%
data.shape 
#it has 953 rows and 24 columns
# Out:
# (953, 24)

# %%
data.size
#total number of elements
# Out:
# 22872

# %% [markdown]
# Display summary and structure of the dataset

# %%
data.info()
#it gives information about the dataframe's structure
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %%
data.describe()
#it gives a statistical summary of the data
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# ...

# %% [markdown]
# Check for unique and duplicate values

# %%
data.nunique()
# Out:
# track_name              943
# artist(s)_name          645
# artist_count              8
# released_year            50
# released_month           12
# released_day             31
# in_spotify_playlists    879
# in_spotify_charts        82
# streams                 949
# in_apple_playlists      234
# in_apple_charts         172
# in_deezer_playlists     348
# in_deezer_charts         34
# in_shazam_charts        198
# bpm                     124
# key                      11
# mode                      2
# danceability_%           72
# valence_%                94
# energy_%                 80
# acousticness_%           98
# instrumentalness_%       39
# liveness_%               68
# speechiness_%            48
# dtype: int64

# %% [markdown]
# Calculating the track and it's artist with most and least streams in 2023

# %%
#MOST STREAMS
max_streams=data['streams'].max
artist_max_streams=data.loc[data['streams'].idxmax(),'artist(s)_name']
print("Artist Name: ",artist_max_streams)
track_max_streams=data.loc[data['streams'].idxmax(),'track_name']
print("Track Name: ",track_max_streams)
# Out:
# Artist Name:  The Weeknd
# Track Name:  Blinding Lights

# %%
#MIN STREAMS
min_streams=data['streams'].min
artist_min_streams=data.loc[data['streams'].idxmin(),'artist(s)_name']
print("Artist Name: ",artist_max_streams)
track_min_streams=data.loc[data['streams'].idxmin(),'track_name']
print("Track Name: ",track_min_streams)
# Out:
# Artist Name:  The Weeknd
# Track Name:  Que Vuelvas

# %% [markdown]
# Number of Tracks Per Artist

# %%
count_tracks_artist=data.groupby('artist(s)_name')['track_name'].count()
print(count_tracks_artist)
print("Maximum Number of Tracks by an Artist: ",count_tracks_artist.max())
# Out:
# artist(s)_name
# (G)I-DLE                                         2
# 21 Savage, Gunna                                 1
# 24kgoldn, Iann Dior                              1
# 50 Cent                                          1
# A$AP Rocky, Metro Boomin, Roisee                 1
#                                                 ..
# j-hope                                           1
# j-hope, J. Cole                                  1
# sped up 8282                                     1
# sped up nightcore, ARIZONATEARS, Lil Uzi Vert    1
# teto                                             1
# Name: track_name, Length: 645, dtype: int64
# Maximum Number of Tracks by an Artist:  34

# %% [markdown]
# Artist having maximum number of tracks

# %%
artist_max_tracks=count_tracks_artist.idxmax()
print("Artist with highest number of tracks: ",artist_max_tracks)
# Out:
# Artist with highest number of tracks:  Taylor Swift

# %% [markdown]
# Using a pie chart we can determine the years of the songs which were streamed in 2023

# %%
'''We grouped the release year of the songs in one variable and showed the release year of the songs which were streamed in 2023'''
yrs_grouped=data.groupby('released_year')['released_year'].value_counts().tail(10)
plt.figure(figsize=(10,8))
plt.pie(yrs_grouped,labels=yrs_grouped.index,autopct='%1.1f%%',colors=['red','blue','green','yellow','pink','orange','hotpink','lightblue','brown','cyan'])
plt.title("Distribution of Streams by Song Release Year (Spotify 2023)")
plt.show()

# %% [markdown]
# Calculating mean and median of spotify streams in 2023

# %% [markdown]
# Interpretation: Some of the most streamed songs in 2023 were from 2022, followed by 2023 and 2021. Most people were listening to the recent songs especially those from 2022 and 2023 , while fewers songs which were streamed were from previosu years. This indicates new music trends in the industry.

# %%
data['streams']=pd.to_numeric(data['streams'],errors='coerce')
avg_streams=data['streams'].mean()
print("Average Streams = ",avg_streams)
# Out:
# Average Streams =  514137424.93907565

# %%
med_streams=data['streams'].median()
print("Median of Streams = ",med_streams)
# Out:
# Median of Streams =  290530915.0

# %% [markdown]
# Top 5 Songs and Artists

# %%
top_5_songs = data.nlargest(5, 'streams')[['artist(s)_name', 'track_name']]
print(top_5_songs)
# Out:
#             artist(s)_name                                     track_name
# 55              The Weeknd                                Blinding Lights
# 179             Ed Sheeran                                   Shape of You
# 86           Lewis Capaldi                              Someone You Loved
# 620            Tones and I                                   Dance Monkey
# 41   Post Malone, Swae Lee  Sunflower - Spider-Man: Into the Spider-Verse

# %% [markdown]
# Top 10 tracks in the apple playlist and visualize the distribution

# %%
top_10_tracks=data.nlargest(10,'in_apple_charts')[['track_name','in_apple_charts']].sort_values(by='in_apple_charts', ascending=False)
print(top_10_tracks)

plt.figure(figsize=(8,6))
plt.bar(top_10_tracks['track_name'],top_10_tracks['in_apple_charts'],color='blue')
plt.xticks(rotation=45, ha='right') 
plt.xlabel("Track Name")
plt.ylabel("Performance in Apple Charts")
plt.title("Top 10 Tracks in Apple Charts")
plt.show()
# Out:
#                                             track_name  in_apple_charts
# 872                                          Last Last              275
# 888                                    Mary On A Cross              266
# 0                  Seven (feat. Latto) (Explicit Ver.)              263
# 17   What Was I Made For? [From The Motion Picture ...              227
# 6                                      Ella Baila Sola              222
# 12                                             Flowers              215
# 5                                             Sprinter              213
# 16                                   Cupid - Twin Ver.              212
# 8                                             fukumean              210
# 2                                              vampire              207

# %% [markdown]
# Top 10 artists in apple playlists and visualize

# %%
top_10_artist=data.nlargest(10,'in_apple_playlists')[['artist(s)_name','in_apple_playlists']].sort_values(by='in_apple_playlists', 
                                                                                                          ascending=False)
print(top_10_artist)

plt.figure(figsize=(8,6))
plt.bar(top_10_artist['artist(s)_name'],top_10_artist['in_apple_playlists'],color='orange')
plt.xticks(rotation=45, ha='right') 
plt.xlabel("Artist Name")
plt.ylabel("Performance in Apple Playlists")
plt.title("Top 10 Artists in Apple Playlists")
plt.show()
# Out:
#                    artist(s)_name  in_apple_playlists
# 55                     The Weeknd                 672
# 403       Calvin Harris, Dua Lipa                 537
# 620                   Tones and I                 533
# 407                      Dua Lipa                 532
# 84   Justin Bieber, The Kid Laroi                 492
# 693  Shawn Mendes, Camila Cabello                 453
# 86                  Lewis Capaldi                 440
# 127                  Harry Styles                 437
# 162           Drake, WizKid, Kyla                 433
# 14                   Harry Styles                 403

# %% [markdown]
# Using a pair-plot to determine how danceability and BPM impact the streams.

# %%
import seaborn as sns

# %%
sns.pairplot(data[['streams', 'bpm', 'danceability_%','released_year']], diag_kind="kde",hue='released_year')
plt.show()

# %% [markdown]
# Interpretation: Most songs in the dataset are from recent years and while songs have different BPM and danceability, only a few get very high stream counts.

# %% [markdown]
# Monthly Streams and Visualize

# %%
monthly_streams=data.groupby('released_month')['streams'].sum().sort_index(ascending=True)
print(monthly_streams)
# Out:
# released_month
# 1     9.675832e+10
# 2     2.154236e+10
# 3     4.102652e+10
# 4     2.667363e+10
# 5     5.320564e+10
# 6     3.526384e+10
# 7     2.989494e+10
# 8     2.903822e+10
# 9     4.114008e+10
# 10    4.298988e+10
# 11    4.420738e+10
# 12    2.771800e+10
# Name: streams, dtype: float64

# %%
plt.figure(figsize=(8,6))
plt.bar(monthly_streams.index,monthly_streams.values,color='green')
plt.title("Month-Wise Streams")
plt.xlabel("Month")
plt.ylabel("Streams")
'''using xticks for displaying the months'''
plt.xticks(range(1,13), ["Jan", "Feb", "Mar", "Apr", "May", "Jun","Jul", "Aug", "Sep", "Oct", "Nov", "Dec"])
plt.show()

# %% [markdown]
# Interpretation: January saw the highest number of streams on Spotify followed by May and November. February saw a drop in the
# streams which suggests fewer high-performing releases.

# %% [markdown]
# Calculating total streams of an individual artist

# %%
grouping_artists=data.groupby('artist(s)_name')['streams'].sum()
print(grouping_artists)
ts_artist=grouping_artists.loc['Selena Gomez']
# Out:
# artist(s)_name
# (G)I-DLE                                         2.669833e+08
# 21 Savage, Gunna                                 6.068094e+07
# 24kgoldn, Iann Dior                              1.699402e+09
# 50 Cent                                          1.202723e+09
# A$AP Rocky, Metro Boomin, Roisee                 9.418647e+07
#                                                      ...
# j-hope                                           1.557958e+08
# j-hope, J. Cole                                  1.165998e+08
# sped up 8282                                     1.037625e+08
# sped up nightcore, ARIZONATEARS, Lil Uzi Vert    2.070333e+08
# teto                                             1.391938e+08
# Name: streams, Length: 645, dtype: float64

# %%
print("\nStreams of Selena Gomez: ",ts_artist)
# Out:
# Streams of Selena Gomez:  91473363.0
